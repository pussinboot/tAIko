# %%
score_crop = test_frame[52:68,-94:-10,:]
show_screen(score_crop)

# %%
last_score = 0
test_all = []
for e_id in range(1, 7036, 1):
    t_frame = clean_pic(extract_path + '/out-{}.png'.format(e_id))
    scores = update_score(t_frame)
    last_score = scores[0]
    test_all += [scores]

# %% [markdown]
# this was using an mse measure

# %%
threshvals = [t[2] for t in test_all]
thresh_np = np.asarray(threshvals)

# %%
plt.figure(figsize=(12,8))
plt.plot(thresh_np)
plt.show()

# %%
np.percentile(thresh_np, 95, axis=0)
# Out:
# array([ 27.94618056,  39.303125  ,  40.52083333,  41.35711806,
#         76.76388889,  83.69618056,  84.46701389])

# %% [markdown]
# this was using abs_diff, which is the better choice

# %%
absdiff_thresh = [t[2] for t in test_all]
adt_np = np.asarray(absdiff_thresh)

# %%
plt.figure(figsize=(12,8))
plt.plot(adt_np)
plt.show()

# %% [markdown]
# as game goes on, bigger decimal places more clearly fall below a threshold so we pick this one
